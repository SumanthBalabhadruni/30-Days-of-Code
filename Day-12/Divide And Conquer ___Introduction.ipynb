# %% [markdown]
# # Divide and Conquer Algorithm

# %% [markdown]
# ## Definition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Working

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Property

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Algorithms which follows **Divide and Conquer**
#
# *   Merge Sort
# *   List item

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
